# %% [markdown]
# # Cascading Risk and Systemic Decision Failure\n\nNotebook placeholder for the Python cascading-risk and systemic-failure walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
