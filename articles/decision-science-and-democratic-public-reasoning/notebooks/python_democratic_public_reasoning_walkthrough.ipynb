# %% [markdown]
# # Decision Science and Democratic Public Reasoning\n\nNotebook placeholder for the Python democratic-public-reasoning walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
