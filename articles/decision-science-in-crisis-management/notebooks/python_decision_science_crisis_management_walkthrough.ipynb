# %% [markdown]
# # Decision Science in Crisis Management
#
# Notebook placeholder for the Python crisis-management decision science walkthrough.
#
# Use the scripts in `../python/` as the reproducible source of truth.
