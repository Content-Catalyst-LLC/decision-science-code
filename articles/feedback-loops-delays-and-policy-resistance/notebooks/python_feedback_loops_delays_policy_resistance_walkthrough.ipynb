# %% [markdown]
# # Feedback Loops, Delays, and Policy Resistance\n\nNotebook placeholder for the Python feedback-delay-policy-resistance walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
