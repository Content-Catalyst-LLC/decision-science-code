# %% [markdown]
# # Forecasting and Decision Support\n\nNotebook placeholder for the Python forecasting and decision-support walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
