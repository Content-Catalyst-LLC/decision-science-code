# %% [markdown]
# # Future Directions in Decision Science\n\nNotebook placeholder for the Python future decision-science walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
