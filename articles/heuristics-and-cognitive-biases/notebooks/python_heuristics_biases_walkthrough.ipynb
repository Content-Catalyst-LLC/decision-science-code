# %% [markdown]
# # Heuristics and Cognitive Biases\n\nNotebook placeholder for the Python heuristics and cognitive-bias walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
