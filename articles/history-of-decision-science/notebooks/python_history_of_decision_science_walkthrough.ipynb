# %% [markdown]
# # The History of Decision Science\n\nNotebook placeholder for the Python historical decision-paradigm walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
