# %% [markdown]
# # Path Dependence, Lock-In, and Decision Timing\n\nNotebook placeholder for the Python path-dependence and lock-in walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
