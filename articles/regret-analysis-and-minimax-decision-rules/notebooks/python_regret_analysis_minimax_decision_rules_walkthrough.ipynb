# %% [markdown]
# # Regret Analysis and Minimax Decision Rules\n\nNotebook placeholder for the Python regret-analysis and minimax-decision-rule walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
