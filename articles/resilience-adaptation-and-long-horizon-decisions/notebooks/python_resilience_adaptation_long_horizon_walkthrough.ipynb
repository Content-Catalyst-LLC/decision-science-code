# %% [markdown]
# # Resilience, Adaptation, and Long-Horizon Decisions\n\nNotebook placeholder for the Python resilience and long-horizon decision walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
