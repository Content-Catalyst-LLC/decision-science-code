# %% [markdown]
# # Stakeholder Values and Decision Legitimacy\n\nNotebook placeholder for the Python stakeholder-values and decision-legitimacy walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
