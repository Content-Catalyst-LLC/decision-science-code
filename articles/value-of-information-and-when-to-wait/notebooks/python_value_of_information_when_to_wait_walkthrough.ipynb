# %% [markdown]
# # Value of Information and When to Wait\n\nNotebook placeholder for the Python value-of-information walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
