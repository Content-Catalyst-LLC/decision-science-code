# %% [markdown]
# # What Is Decision Science?\n\nNotebook placeholder for the Python decision science walkthrough.\n\nUse the scripts in `../python/` as the source of truth for reproducible workflows.
