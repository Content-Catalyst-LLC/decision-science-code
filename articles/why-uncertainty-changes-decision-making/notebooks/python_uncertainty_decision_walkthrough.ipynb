# %% [markdown]
# # Why Uncertainty Changes Decision-Making\n\nNotebook placeholder for the Python uncertainty decision walkthrough.\n\nUse the scripts in `../python/` as the reproducible source of truth.
